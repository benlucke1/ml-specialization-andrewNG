# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X_train = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y_train = np.array([0, 0, 0, 1, 1, 1])
bc = list()
rx = list()
fig, ax = plt.subplots(dpi=350)
ax.set_xlim(0,4)
ax.set_ylim(0,4)
for item in X_train:
    if (item[0] ==3 or item[0] ==2) or ((item[0] == 1 and item[1] == 2.5)):
        rx.append(item)
    else:
        bc.append(item)
display(bc)
bc = np.array(bc)
rx = np.array(bc)
#ax.scatter(bc[:,0],bc[:,1],marker='o',color='blue',facecolors='none',lw=3,label='y=0')
#ax.scatter(rx[0],rx[1],marker='x',color='red',lw=3,label='y=1')
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
plt.show()
# Out:
# [array([0.5, 1.5]), array([1., 1.]), array([1.5, 0.5])]

# %%
def sigmoid(z):
    ret = 1/(1+np.exp(-z))
    return ret

def gradients(X, y, f_wb, w, b):
    m = X.shape[0]
    dj_dw = 0
    dj_db = 0
    
    dj_dw_incremental = sum([(f_wb(z[k])-y[k])*y[k] for k in range(len(X))])/m
    dj_db_incremental = sum([(f_wb(X[k])-y[k]) for k in range(len(X))])/m    
    
    print(dj_dw_incremental,dj_db_incremental)

# %%
x = np.array([[0, 1, 2],[5,2,1]])
w = np.array([1,5,2]).reshape(1,3)
b = -9
z = w@x.T + b
z
y = [0, 1]

# %%
sum((sigmoid(z) - y).T*w)
# Out:
# array([0.49966465, 2.49832325, 0.9993293 ])
